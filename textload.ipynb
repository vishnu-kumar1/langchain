# %% [markdown]
# # from langchain_community.vectorstores import FAISS
#
# # vector_store = FAISS.from_documents(result5,embed_model)
#
# # def rag(query,top_k=2):
# #     # query_embedding = embed_model.embed_query(query)
# #     docs = vector_store.similarity_search(query, k=top_k)
# #     return docs
#
# # print(rag("What is deep learning?"))

# %%
from langchain_community.document_loaders import TextLoader

# %%
# # TextLoader is a LangChain document loader used to read text files (.txt) and convert them into LangChain Document objects.

# The loader:
# Reads file content
# Wraps it into a standard structure
# Adds metadata support
# Makes the data compatible with LangChain workflows

# %%
txt_loader = TextLoader(file_path='content.txt')

# %%
type(txt_loader)
# Out:
# langchain_community.document_loaders.text.TextLoader

# %%
doc = txt_loader.load()  #(method) def load() -> list[Document]
doc[0].page_content
# Out:
# 'Gen ai is a powerful tool that can generate human-like text based on the input it receives. It uses deep learning algorithms to understand and mimic natural language, allowing it to create coherent and contextually relevant content. Gen ai can be used for a variety of applications, including writing articles, creating marketing copy, generating code, and even composing poetry. Its ability to produce high-quality content quickly makes it a valuable resource for businesses and individuals looking to save time and enhance their creative output.However, it is important to use Gen ai responsibly, as it can also be used to create misleadingor harmful content. It is crucial to ensure that the generated content is accurate, ethical, and does not violate any guidelines or regulations. As with any tool, it is essential to understand its capabilities andlimitations to make the most of its potential while minimizing any negative impacts.Overall, Gen ai has the potential to revolutionize the way we create and consume content, offering new opportunities for innovation and creativity. By harnessing the power of Gen ai, we can unlock new possibilities and push the boundaries of what is possible in the world of content creation.'

# %%
import spacy
from langchain_text_splitters import RecursiveCharacterTextSplitter

nlp = spacy.load("en_core_web_sm")

text = '''
Artificial Intelligence (AI) is one of the most transformative technologies of the modern era. It refers to the simulation of human intelligence in machines that are programmed to think, learn, and make decisions. AI systems are designed to perform tasks such as problem-solving, speech recognition, decision-making, and language translation—tasks that traditionally required human intelligence.

AI is not a single technology but a broad field that includes several subfields such as machine learning, deep learning, natural language processing, computer vision, and robotics. These areas work together to create intelligent systems capable of handling complex tasks.
'''

doc = nlp(text)
processed_text = " ".join([ token.lemma_ for token in doc if not token.is_punct ])

splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20
)

chunks = splitter.split_text(processed_text)

print(chunks)
# Out:
# ['Artificial Intelligence AI be one of the most transformative technology of the modern era it refer', 'modern era it refer to the simulation of human intelligence in machine that be program to think', 'be program to think learn and make decision AI system be design to perform task such as problem', 'such as problem solve speech recognition decision making and language translation task that', 'task that traditionally require human intelligence', 'AI be not a single technology but a broad field that include several subfield such as machine', 'such as machine learning deep learning natural language processing computer vision and robotic', 'vision and robotic these area work together to create intelligent system capable of handle complex', 'of handle complex task']

# %%
chunks
# Out:
# ['Artificial Intelligence AI be one of the most transformative technology of the modern era it refer',
#  'modern era it refer to the simulation of human intelligence in machine that be program to think',
#  'be program to think learn and make decision AI system be design to perform task such as problem',
#  'such as problem solve speech recognition decision making and language translation task that',
#  'task that traditionally require human intelligence',
#  'AI be not a single technology but a broad field that include several subfield such as machine',
#  'such as machine learning deep learning natural language processing computer vision and robotic',
#  'vision and robotic these area work together to create intelligent system capable of handle complex',
#  'of handle complex task']

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embed_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2") #Teh default size of all-MiniLM-L6-v2 is 384 dimensions
embed_model
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, query_encode_kwargs={}, multi_process=False, show_progress=False)

# %%
embeddings = embed_model.embed_documents(chunks)
embeddings

# %%
print(len(embeddings[0]))

# %%
result5 = splitter.create_documents([processed_text])    
result5

# %%
for doc, emb in zip(result5, embeddings):
    doc.metadata["hf_embedding"] = emb
result5

# %% [markdown]
# AIzaSyCuM9Dd0a7Nv9h9oF41C8efLQ4kt_jdzTU

# %%
from langchain_community.vectorstores import FAISS

# %%
vector_store = FAISS.from_documents(result5,embed_model)

# %%
def rag(query,top_k=2):
    # query_embedding = embed_model.embed_query(query)
    docs = vector_store.similarity_search(query, k=top_k)
    return docs

print(rag("What is deep learning?"))

# %%
chunks = "\n\n".join(chunks)

# %%
chunks
